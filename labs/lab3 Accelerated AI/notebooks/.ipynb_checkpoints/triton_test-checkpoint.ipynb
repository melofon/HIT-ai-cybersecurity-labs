# %%
# !pip install tritonclient[all]
# Out:
# Requirement already satisfied: tritonclient[all] in /opt/conda/lib/python3.13/site-packages (2.63.0)
# Requirement already satisfied: numpy>=1.19.1 in /opt/conda/lib/python3.13/site-packages (from tritonclient[all]) (2.3.5)
# Requirement already satisfied: perf-analyzer in /opt/conda/lib/python3.13/site-packages (from tritonclient[all]) (2.59.1)
# Requirement already satisfied: python-rapidjson>=0.9.1 in /opt/conda/lib/python3.13/site-packages (from tritonclient[all]) (1.23)
# Requirement already satisfied: urllib3>=2.0.7 in /opt/conda/lib/python3.13/site-packages (from tritonclient[all]) (2.6.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.1 in /opt/conda/lib/python3.13/site-packages (from tritonclient[all]) (3.13.2)
# Requirement already satisfied: cuda-python in /opt/conda/lib/python3.13/site-packages (from tritonclient[all]) (13.1.1)
# Requirement already satisfied: geventhttpclient>=2.3.3 in /opt/conda/lib/python3.13/site-packages (from tritonclient[all]) (2.3.7)
# Requirement already satisfied: grpcio<1.68,>=1.63.0 in /opt/conda/lib/python3.13/site-packages (from tritonclient[all]) (1.67.1)
# Requirement already satisfied: packaging>=14.1 in /opt/conda/lib/python3.13/site-packages (from tritonclient[all]) (25.0)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in /opt/conda/lib/python3.13/site-packages (from tritonclient[all]) (5.29.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (3.11)
# Requirement already satisfied: gevent in /opt/conda/lib/python3.13/site-packages (from geventhttpclient>=2.3.3->tritonclient[all]) (25.9.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.13/site-packages (from geventhttpclient>=2.3.3->tritonclient[all]) (2025.11.12)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.13/site-packages (from geventhttpclient>=2.3.3->tritonclient[all]) (1.2.0)
# Requirement already satisfied: cuda-bindings~=13.1.1 in /opt/conda/lib/python3.13/site-packages (from cuda-python->tritonclient[all]) (13.1.1)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /opt/conda/lib/python3.13/site-packages (from cuda-python->tritonclient[all]) (1.3.3)
# Requirement already satisfied: greenlet>=3.2.2 in /opt/conda/lib/python3.13/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[all]) (3.3.0)
# Requirement already satisfied: zope.event in /opt/conda/lib/python3.13/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[all]) (6.1)
# Requirement already satisfied: zope.interface in /opt/conda/lib/python3.13/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[all]) (8.1.1)

# %%
import os
import tritonclient.http as httpclient

#triton_url = os.environ.get("TRITON_HTTP_URL", "triton:8000")
triton_url = "triton:8000"
print("TRITON_HTTP_URL:", triton_url)

client = httpclient.InferenceServerClient(url=triton_url, verbose=True)

print("Server live :", client.is_server_live())
print("Server ready:", client.is_server_ready())

server_metadata = client.get_server_metadata()
print(f"server metadata: {server_metadata}")

repo_index = client.get_model_repository_index()
print(f"list of models: {repo_index}")
# Out:
# TRITON_HTTP_URL: triton:8000
# GET /v2/health/live, headers {}
# <HTTPSocketPoolResponse status=400 headers={'Content-Length': '0', 'Content-Type': 'text/plain'}>
# Server live : False
# GET /v2/health/ready, headers {}
# <HTTPSocketPoolResponse status=400 headers={'Content-Length': '0', 'Content-Type': 'text/plain'}>
# Server ready: False
# GET /v2, headers {}
# <HTTPSocketPoolResponse status=200 headers={'Content-Type': 'application/json', 'Content-Length': '285'}>
# bytearray(b'{"name":"triton","version":"2.50.0","extensions":["classification","sequence","model_repository","model_repository(unload_dependents)","schedule_policy","model_configuration","system_shared_memory","cuda_shared_memory","binary_tensor_data","parameters","statistics","trace","logging"]}')
# server metadata: {'name': 'triton', 'version': '2.50.0', 'extensions': ['classification', 'sequence', 'model_repository', 'model_repository(unload_dependents)', 'schedule_policy', 'model_configuration', 'system_shared_memory', 'cuda_shared_memory', 'binary_tensor_data', 'parameters', 'statistics', 'trace', 'logging']}
# POST /v2/repository/index, headers {}
#
# <HTTPSocketPoolResponse status=503 headers={'Content-Type': 'application/json', 'Content-Length': '28'}>
# ---------------------------------------------------------------------------
# InferenceServerException                  Traceback (most recent call last)
# Cell In[2], line 16
#      13 server_metadata = client.get_server_metadata()
#      14 print(f"server metadata: {server_metadata}")
# ---> 16 repo_index = client.get_model_repository_index()
#      17 print(f"list of models: {repo_index}")
#
# File /opt/conda/lib/python3.13/site-packages/tritonclient/http/_client.py:612, in InferenceServerClient.get_model_repository_index(self, headers, query_params)
#     605 request_uri = "v2/repository/index"
#     606 response = self._post(
#     607     request_uri=request_uri,
#     608     request_body="",
#     609     headers=headers,
#     610     query_params=query_params,
#     611 )
# --> 612 _raise_if_error(response)
#     614 content = response.read()
#     615 if self._verbose:
#
# File /opt/conda/lib/python3.13/site-packages/tritonclient/http/_utils.py:69, in _raise_if_error(response)
#      67 error = _get_error(response)
#      68 if error is not None:
# ---> 69     raise error
#
# InferenceServerException: [503] Server not ready
